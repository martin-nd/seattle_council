# %%
import polars as pl
from polars import col as c
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.stats as stats
data = pl.read_csv("clean_tendency_data.csv")
data = data.with_columns(c("date").cast(pl.Date))

# %%
sb.histplot(data, x = "budget", hue = "councilmember")
# Out:
# /Users/martin/anaconda3/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/martin/anaconda3/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/martin/anaconda3/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
data.columns
# Out:
# ['date',
#  'councilmember',
#  'budget',
#  'traffic',
#  'public transit',
#  'utilities-light',
#  'utilities-heat',
#  'utilities-water',
#  'utilities-electric',
#  'civil unrest',
#  'civil rights',
#  'parks',
#  'labor',
#  'housing',
#  'homelessness',
#  'political-legislation',
#  'political-city council',
#  'political-mayor',
#  'political-general',
#  'crime',
#  'police-general',
#  'police-controversy',
#  'police-political',
#  'public safety',
#  'public health',
#  'public services',
#  'covid-general',
#  'covid-vaccines',
#  'covid-masks',
#  'infrastructure',
#  'business',
#  'real estate',
#  'welfare-unemployment',
#  'welfare-food',
#  'economics',
#  'environmental',
#  'sports']
